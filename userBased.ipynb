# %% [markdown]
# Data Reading

# %%
import pandas as pd

movies_df = pd.read_csv('./resources/movies.csv')
ratings_df = pd.read_csv('./resources/ratings.csv')

print(ratings_df.shape)
ratings_df.head()
# Out:
# (100836, 4)
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# Lets reduce the number of rows in ratings_df by only considering movies relevant enough to be given atleast 100 ratings in order to ease computation

# %%
agg_ratings = ratings_df.groupby('movieId').movieId.count()
agg_ratings_gt100 = agg_ratings[agg_ratings.values > 100]

ratings_reduced = ratings_df[ratings_df.movieId.isin(agg_ratings_gt100.index)]
print(ratings_reduced.shape)
ratings_reduced.head()
# Out:
# (19788, 4)
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 7       1      110     4.0  964982176

# %% [markdown]
# To find how much each user is related to each other based on how they rate movies, let's apply Pearson's correlation on a dataframe with userId as index, movieId as columns & each cell indicating the ratings given by a particular user on a specific movie

# %%
movieUserMatrix = ratings_reduced.pivot(index='userId', columns='movieId', values='rating')
print(movieUserMatrix.shape)
movieUserMatrix.head()
# Out:
# (597, 134)
# movieId  1      2      6      10     32     34     39     47     50     110    \
# userId
# 1          4.0    NaN    4.0    NaN    NaN    NaN    NaN    5.0    5.0    4.0
# 2          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4          NaN    NaN    NaN    NaN    2.0    NaN    NaN    2.0    NaN    NaN
# 5          4.0    NaN    NaN    NaN    NaN    4.0    3.0    NaN    4.0    4.0
#
# movieId  ...  7153   7361   7438   8961   33794  48516  58559  60069  68954  \
# userId   ...
# 1        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2        ...    NaN    NaN    NaN    NaN    NaN    4.0    4.5    NaN    NaN
# 3        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# movieId  79132
# userId
# 1          NaN
# 2          4.0
# 3          NaN
# 4          NaN
# 5          NaN
#
# [5 rows x 134 columns]

# %% [markdown]
# Let's normalize movieRatingsMatrix

# %%
movieUserMatrix_norm = movieUserMatrix.subtract(movieUserMatrix.mean(axis=1), axis=0)
print(movieUserMatrix_norm.shape)
movieUserMatrix_norm.head()
# Out:
# (597, 134)
# movieId     1      2         6      10        32        34        39     \
# userId
# 1       -0.392857    NaN -0.392857    NaN       NaN       NaN       NaN
# 2             NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 3             NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 4             NaN    NaN       NaN    NaN -1.382353       NaN       NaN
# 5        0.538462    NaN       NaN    NaN       NaN  0.538462 -0.461538
#
# movieId     47        50        110    ...  7153   7361   7438   8961   33794  \
# userId                                 ...
# 1        0.607143  0.607143 -0.392857  ...    NaN    NaN    NaN    NaN    NaN
# 2             NaN       NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN
# 3             NaN       NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN
# 4       -1.382353       NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN
# 5             NaN  0.538462  0.538462  ...    NaN    NaN    NaN    NaN    NaN
#
# movieId  48516  58559  60069  68954  79132
# userId
# 1          NaN    NaN    NaN    NaN    NaN
# 2          0.0    0.5    NaN    NaN    0.0
# 3          NaN    NaN    NaN    NaN    NaN
# 4          NaN    NaN    NaN    NaN    NaN
# 5          NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 134 columns]

# %% [markdown]
# Applying Pearson's Correlation on movieUserMatrix

# %%
user_similarity = movieUserMatrix_norm.T.corr()
print(user_similarity.shape)
user_similarity.head()
# Out:
# (597, 597)
# userId       1    2    3         4         5         6         7         8    \
# userId
# 1       1.000000  NaN  NaN  0.391797  0.180151 -0.439941 -0.029894  0.464277
# 2            NaN  1.0  NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 4       0.391797  NaN  NaN  1.000000 -0.394823  0.421927  0.704669  0.055442
# 5       0.180151  NaN  NaN -0.394823  1.000000 -0.006888  0.328889  0.030168
#
# userId  9         10   ...           601       602       603       604  \
# userId                 ...
# 1       1.0 -0.037987  ...  9.157371e-02  0.254514  0.101482 -0.500000
# 2       NaN  1.000000  ... -5.833333e-01       NaN -1.000000       NaN
# 3       NaN       NaN  ...           NaN       NaN       NaN       NaN
# 4       NaN  0.360399  ... -2.393249e-01  0.562500  0.162301 -0.158114
# 5       NaN -0.777714  ... -4.532467e-17  0.231642  0.131108  0.068621
#
# userId       605       606       607       608       609       610
# userId
# 1       0.780020  0.303854 -0.012077  0.242309 -0.175412  0.071553
# 2            NaN  0.583333       NaN -0.229416       NaN  0.765641
# 3            NaN       NaN       NaN       NaN       NaN       NaN
# 4       0.905134  0.021898 -0.020659 -0.286872       NaN -0.050868
# 5      -0.245026  0.377341  0.228218  0.263139  0.384111  0.040582
#
# [5 rows x 597 columns]

# %% [markdown]
# Now, let's get the recommended movies for a certain "picked_user"

# %%
picked_user = 1

user_similarity.drop(index=picked_user, inplace=True)

# %% [markdown]
# Let's find the 10 most similar users to the "picked_user"

# %%
similarity_threshold = 0.3
user_similarity_pickedUser = user_similarity[picked_user]
similar_users = user_similarity_pickedUser[user_similarity_pickedUser.values > similarity_threshold].sort_values(ascending=False)[0:10]
similar_users
# Out:
# userId
# 502    1.000000
# 598    1.000000
# 550    1.000000
# 108    1.000000
# 9      1.000000
# 401    0.942809
# 511    0.925820
# 366    0.872872
# 154    0.866025
# 595    0.866025
# Name: 1, dtype: float64

# %% [markdown]
# Now let's get the movies that have been watched by these 10 users

# %%
movies_watched = movieUserMatrix_norm[movieUserMatrix_norm.index == picked_user].dropna(axis=1,how='all')
movies_watched
# Out:
# movieId      1         6         47        50        110       223       231   \
# userId
# 1       -0.392857 -0.392857  0.607143  0.607143 -0.392857 -1.392857  0.607143
#
# movieId      260       296       316   ...      2115      2329      2571  \
# userId                                 ...
# 1        0.607143 -1.392857 -1.392857  ...  0.607143  0.607143  0.607143
#
# movieId      2628      2716      2858      2959      3147      3578      3793
# userId
# 1       -0.392857  0.607143  0.607143  0.607143  0.607143  0.607143  0.607143
#
# [1 rows x 56 columns]

# %%
similar_movies = movieUserMatrix_norm[movieUserMatrix_norm.index.isin(similar_users.index)].dropna(axis=1,how='all')
print(similar_movies.shape)
similar_movies.head()
# Out:
# (10, 62)
# movieId     1      50        110       223    318       356       364    \
# userId
# 9             NaN    NaN       NaN -0.666667    NaN       NaN       NaN
# 108           NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 154           NaN    NaN       NaN       NaN    NaN  0.214286       NaN
# 366           NaN    NaN -0.205882       NaN    NaN       NaN       NaN
# 401      0.117647    NaN       NaN       NaN    NaN  0.117647  0.117647
#
# movieId     480    527       541    ...     7153   7361      7438      8961   \
# userId                              ...
# 9             NaN    NaN       NaN  ...       NaN    NaN       NaN       NaN
# 108     -0.533333    NaN  0.466667  ...       NaN    NaN       NaN       NaN
# 154           NaN    NaN       NaN  ...       NaN    NaN       NaN       NaN
# 366           NaN    NaN       NaN  ...  0.294118    NaN -0.205882 -0.205882
# 401           NaN    NaN       NaN  ... -0.382353    NaN       NaN  0.617647
#
# movieId     33794     48516     58559     60069     68954     79132
# userId
# 9             NaN       NaN       NaN       NaN       NaN       NaN
# 108           NaN       NaN       NaN       NaN       NaN       NaN
# 154           NaN       NaN       NaN       NaN  0.214286  0.214286
# 366     -0.205882  0.294118 -0.205882       NaN       NaN -0.205882
# 401           NaN       NaN       NaN  0.617647  0.617647       NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# Now let's get the movies that have been watched by these 10 users which haven't been watched by "picked_user"

# %%
similar_movies.drop(movies_watched.columns, axis=1, inplace=True, errors='ignore')
# similar_movies.head()
# print(similar_movies_reduced.shape)
# similar_movies_reduced.head()
# similar_movies.columns
# movies_watched.columns
similar_movies_reduced = similar_movies
similar_movies_reduced.head()
# Out:
# movieId  318       364       541       588       589       595       1036   \
# userId
# 9          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108        NaN       NaN  0.466667       NaN       NaN       NaN       NaN
# 154        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 366        NaN       NaN       NaN       NaN -0.205882       NaN -0.205882
# 401        NaN  0.117647       NaN -0.382353       NaN -0.382353       NaN
#
# movieId     1704      1721      1968   ...     7153   7361      7438   \
# userId                                 ...
# 9             NaN       NaN       NaN  ...       NaN    NaN       NaN
# 108           NaN -0.533333 -0.533333  ...       NaN    NaN       NaN
# 154      0.214286       NaN       NaN  ...       NaN    NaN       NaN
# 366           NaN       NaN       NaN  ...  0.294118    NaN -0.205882
# 401           NaN       NaN       NaN  ... -0.382353    NaN       NaN
#
# movieId     8961      33794     48516     58559     60069     68954     79132
# userId
# 9             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 154           NaN       NaN       NaN       NaN       NaN  0.214286  0.214286
# 366     -0.205882 -0.205882  0.294118 -0.205882       NaN       NaN -0.205882
# 401      0.617647       NaN       NaN       NaN  0.617647  0.617647       NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# Now, to finally compute the recommended movies

# %%
similarityScore_movies = {}
# similar_movies_reduced.columns

for i in similar_movies_reduced.columns:
    total = 0
    count = 0
    
    for j in similar_users.index:
        if pd.isna(similar_movies_reduced[i][j]) == False:
            # rating * similarity_score
            total += similar_movies_reduced[i][j] * similar_users[j]
            count += 1
    
    if count == 0:
        similarityScore_movies[i] = 0
    else:
        similarityScore_movies[i] = total/count


similarityScore_movies = pd.DataFrame(similarityScore_movies.items(), columns=['movieId', 'score'])
similarityScore_movies = similarityScore_movies.sort_values('score',ascending=False)
recommended_movies = pd.merge(similarityScore_movies,movies_df, on='movieId', how='inner')
recommended_movies.head(10)
# Out:
#    movieId     score                                           title  \
# 0     7361  1.888889    Eternal Sunshine of the Spotless Mind (2004)
# 1     5816  1.888889  Harry Potter and the Chamber of Secrets (2002)
# 2     5418  0.888889                     Bourne Identity, The (2002)
# 3     4963  0.888889                           Ocean's Eleven (2001)
# 4    79132  0.587491                                Inception (2010)
# 5     4878  0.466667                             Donnie Darko (2001)
# 6      541  0.466667                             Blade Runner (1982)
# 7     4995  0.466667                        Beautiful Mind, A (2001)
# 8    48516  0.256727                            Departed, The (2006)
# 9      318  0.222566                Shawshank Redemption, The (1994)
#
#                                             genres
# 0                             Drama|Romance|Sci-Fi
# 1                                Adventure|Fantasy
# 2                          Action|Mystery|Thriller
# 3                                   Crime|Thriller
# 4  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 5                    Drama|Mystery|Sci-Fi|Thriller
# 6                           Action|Sci-Fi|Thriller
# 7                                    Drama|Romance
# 8                             Crime|Drama|Thriller
# 9                                      Crime|Drama
